# %%
# Importamos bibliotecas.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Definimos rutas de archivos.
datasets = '../datasets/'
name = 'customer-churn-model/Customer Churn Model.txt'
path = datasets + name

# %%
# Definimos el dataframe.
df = pd.read_csv(path)
df.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# ...

# %%
# Vamos a crear un subconjunto de datos del dataframe original.

# Podemos crear una variable con una columna así, pero el tipo no es un array, sino una 'Serie' de pandas.
acc_len = df['Account Length']
print(type(acc_len))

# Podemos definir un subconjunto con la siguiente sintaxis. Y el objeto es un 'dataframe' de pandas.
subset = df[['Account Length', 'Phone', 'Eve Charge', 'Day Calls']]
subset.head()
# Out:
# <class 'pandas.core.series.Series'>
#    Account Length     Phone  Eve Charge  Day Calls
# 0             128  382-4657       16.78        110
# 1             107  371-7191       16.62        123
# 2             137  358-1921       10.30        114
# 3              84  375-9999        5.26         71
# 4              75  330-6626       12.61        113

# %%
# A veces es más fácil definir las columnas que no deseamos y quedarnos con el complementario.

# Definimos la lista de columnas no deseadas.
cols_not_wanted = ['Account Length', 'Phone', 'Eve Charge', 'Day Calls']

# Definimos la lista completa de columnas.
all_cols = df.columns.tolist()

# Por comprensión definimos la lista de columnas deseadas.
cols_wanted = [x for x in all_cols if x not in cols_not_wanted]

# Definimos el dataset deseado
subset = df[cols_wanted]
subset.head()

# También se puede hacer con:
# a = set(desired_columns)
# b = set(all_columns_list)
# sublist = b-a
# sublist = list(sublist)
# Out:
#   State  Area Code Int'l Plan VMail Plan  VMail Message  Day Mins  Day Charge  \
# 0    KS        415         no        yes             25     265.1       45.07
# 1    OH        415         no        yes             26     161.6       27.47
# 2    NJ        415         no         no              0     243.4       41.38
# 3    OH        408        yes         no              0     299.4       50.90
# 4    OK        415        yes         no              0     166.7       28.34
#
#    Eve Mins  Eve Calls  Night Mins  Night Calls  Night Charge  Intl Mins  \
# 0     197.4         99       244.7           91         11.01       10.0
# 1     195.5        103       254.4          103         11.45       13.7
# 2     121.2        110       162.6          104          7.32       12.2
# 3      61.9         88       196.9           89          8.86        6.6
# 4     148.3        122       186.9          121          8.41       10.1
#
#    Intl Calls  Intl Charge  CustServ Calls  Churn?
# ...

# %%
# También podemos filtrar por filas dado un condicional.
df_dayMins = df[ df['Day Mins'] > 200 ]
df_dayMins.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 5    AL             118        510  391-8027        yes         no
# 6    MA             121        510  355-9993         no        yes
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 5              0     223.4         98       37.98  ...        101       18.75
# 6             24     218.2         88       37.09  ...        108       29.62
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# ...

# %%
# También podemos hacerlo con strings.
df_Ny = df[ df['State'] == 'NY' ]
df_Ny.head()
# Out:
#     State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 15     NY             161        415  351-7269         no         no
# 77     NY             144        408  360-1171         no         no
# 136    NY              75        415  374-8525         no        yes
# 182    NY              67        408  405-2888         no        yes
# 186    NY             106        408  422-1471         no         no
#
#      VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  \
# 15               0     332.9         67       56.59  ...         97
# 77               0      61.6        117       10.47  ...         85
# 136             21     175.8         97       29.89  ...        106
# 182             36     115.6        111       19.65  ...         94
# 186              0     158.7         74       26.98  ...        139
#
#      Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  \
# ...

# %%
# Podemos también hacer un filtrado simultaneo entre columnas y líneas.
df_dobuleFiltred = df[ ['Day Mins', 'Night Mins', 'Account Length'] ][0:50]
df_dobuleFiltred.head()
# Out:
#    Day Mins  Night Mins  Account Length
# 0     265.1       244.7             128
# 1     161.6       254.4             107
# 2     243.4       162.6             137
# 3     299.4       196.9              84
# 4     166.7       186.9              75

# %%
# Así mismo podemos crear columnas definiéndolas en lugar de concatenarlas.
df['Total Mins'] = df['Day Mins'] + df['Night Mins'] + df['Eve Mins']
df['Total calls'] = df['Day Calls'] + df['Night Calls'] + df['Eve Calls']
df.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Night Mins  \
# 0             25     265.1        110       45.07  ...       244.7
# 1             26     161.6        123       27.47  ...       254.4
# 2              0     243.4        114       41.38  ...       162.6
# 3              0     299.4         71       50.90  ...       196.9
# 4              0     166.7        113       28.34  ...       186.9
#
#    Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# 0           91         11.01       10.0           3         2.70
# ...
